# %%
from plotnine import *
import pandas as pd

# %%
airquality = pd.read_csv("airquality.csv", sep=",")
mtcars = pd.read_csv("mtcars.csv", sep=",")

# %%
(ggplot(mtcars)
  + geom_point(aes(x = 'wt', y = 'mpg'))
#  + stat_smooth(method='lm')
  + facet_wrap('~gear')  )
# Out:
# <ggplot: (-9223372029292093117)>
